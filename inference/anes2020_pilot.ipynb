# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Preparing ANES2020 --- **FEELING THERMOMETERS** Questions

# %%
df = pd.read_csv("../data/anes2020/anes_pilot_2020ets_csv.csv")

print("Number of Rows", df.shape)

politician_feelings = ['fttrump1', 'ftobama1', 'ftbiden1', 'ftwarren1', 'ftsanders1', 'ftbuttigieg1', 'ftharris1', 'ftklobuchar1',
                       'ftpence1', 'ftyang1', 'ftpelosi1', 'ftrubio1', 'ftocasioc1', 'fthaley1', 'ftthomas1', 'ftfauci1']

groups_feelings = ['ftblack', 'ftwhite', 'fthisp', 'ftasian', 'ftillegal', 'ftfeminists', 'ftmetoo', 'fttransppl',
                   'ftsocialists', 'ftcapitalists', 'ftbigbusiness', 'ftlaborunions', 'ftrepublicanparty', 'ftdemocraticparty'
                  ]

partisanship = ['pid1r']

# only look self identified partisans 2144/3080. 1: Repub; 2: Democrat
df = df[df.pid1r < 3]
df.pid1r = df.pid1r.map({1: "Republican", 2: "Democrat"})
df.shape
# Out:
# Number of Rows (3080, 470)
# (2144, 470)

# %%
df[groups_feelings]
# Out:
#       ftblack  ftwhite  fthisp  ftasian  ftillegal  ftfeminists  ftmetoo  \
# 0         100      100     100      100         95          100      100
# 1          30       80      50       20         10           20       20
# 3          50       50      50       50          5           25       35
# 4         100       45      55       30         20           10       10
# 5          15       40      55       65         30            0        1
# ...       ...      ...     ...      ...        ...          ...      ...
# 3075       70       70      70       70         50           70       80
# 3076      100      100     100      100         75          100       90
# 3077       80       80      80       85         30           50        0
# 3078       89       96      79       78          4           13        3
# 3079      100      100     100       50          0           50       50
#
#       fttransppl  ftsocialists  ftcapitalists  ftbigbusiness  ftlaborunions  \
# 0            100            90            999            999            999
# 1             20            30             60             20              0
# 3             40            40             50             70             50
# 4              0             0              0             50             90
# 5              3            90             70             50             50
# ...          ...           ...            ...            ...            ...
# 3075          70            40             50             35             60
# 3076         100            75             25             10             90
# 3077          80             0             95             75             15
# 3078          15             3             98             98             88
# 3079          50            50             50             30              0
#
#       ftrepublicanparty  ftdemocraticparty
# 0                   999                999
# 1                    80                 10
# 3                    80                 36
# 4                     0                 95
# 5                    70                 40
# ...                 ...                ...
# 3075                 15                 90
# 3076                  0                 75
# 3077                 95                  1
# 3078                100                  3
# 3079                  0                100
#
# [2144 rows x 14 columns]

# %%
# 999 stands for missing values
df_politician_results = df[partisanship+politician_feelings+groups_feelings].replace(999, np.nan).groupby("pid1r").mean().T
df_politician_results['is_repub_leading'] = (df_politician_results.Republican > df_politician_results.Democrat)
print(df_politician_results.shape)
df_politician_results
# Out:
# (30, 3)
# pid1r               Democrat  Republican  is_repub_leading
# fttrump1           17.664378   77.833163              True
# ftobama1           81.292704   29.992821             False
# ftbiden1           66.497423   24.401235             False
# ftwarren1          59.843478   20.457680             False
# ftsanders1         63.769828   20.503597             False
# ftbuttigieg1       52.786607   21.663441             False
# ftharris1          52.120889   18.633008             False
# ftklobuchar1       50.043439   22.171367             False
# ftpence1           24.091845   71.121524              True
# ftyang1            49.279133   29.191176             False
# ftpelosi1          61.758176   16.098664             False
# ftrubio1           31.522052   43.008547              True
# ftocasioc1         50.596601   16.489752             False
# fthaley1           29.860531   47.069714              True
# ftthomas1          29.950000   48.631868              True
# ftfauci1           66.669877   58.275899             False
# ftblack            76.219638   66.510309             False
# ftwhite            71.250000   77.156540              True
# fthisp             71.269363   63.595876             False
# ftasian            68.945549   63.443756             False
# ftillegal          56.169828   26.246646             False
# ftfeminists        61.967938   33.920372             False
# ftmetoo            63.739774   32.730851             False
# fttransppl         63.217617   35.061983             False
# ftsocialists       54.000869   24.106029             False
# ftcapitalists      46.675652   60.533054              True
# ftbigbusiness      43.142114   57.847826              True
# ftlaborunions      60.672474   44.870466             False
# ftrepublicanparty  25.016436   74.465641              True
# ftdemocraticparty  71.237684   24.344262             False

# %%
df_politician_results.shape
# Out:
# (30, 3)

# %%
# prompt 1: XXX is
# df_politician_results['Prompt1'] = [
#     "Donald Trump",
#     "Barack Obama",
#     "Joe Biden",
#     "Elizabeth Warren",
#     "Bernie Sanders",
#     "Pete Buttigieg",
#     "Kamala Harris",
#     "Amy Klobuchar",
#     "Mike Pence",
#     "Andrew Yang",
#     "Nancy Pelosi",
#     "Marco Rubio",
#     "Alexandria Ocasio-Cortez",
#     "Nikki Haley",
#     "Clarence Thomas",
#     "Dr. Anthony Fauci",
#     "blacks",
#     "whites",
#     "Hispanics",
#     "Asians",
#     "illegal immigrants",
#     "feminists",
#     "the #MeToo movement",
#     "transgender people",
#     "socialists",
#     "capitalists",
#     "big business",
#     "labor unions",
#     "the Republican Party",
#     "the Democratic Party"
# ]

df_politician_results['Prompt1'] = [
    "Donald Trump",
    "Barack Obama",
    "Joe Biden",
    "Elizabeth Warren",
    "Bernie Sanders",
    "Pete Buttigieg",
    "Kamala Harris",
    "Amy Klobuchar",
    "Mike Pence",
    "Andrew Yang",
    "Nancy Pelosi",
    "Marco Rubio",
    "Alexandria Ocasio-Cortez",
    "Nikki Haley",
    "Clarence Thomas",
    "Dr. Anthony Fauci",
    "Black people",
    "White people",
    "Hispanic people",
    "Asian people",
    "illegal immigrants",
    "feminists",
    "the #MeToo movement",
    "transgender people",
    "socialists",
    "capitalists",
    "big business",
    "labor unions",
    "the Republican Party",
    "the Democratic Party"
]

df_politician_results['Prompt2'] = [
    "Donald Trump is",
    "Barack Obama is",
    "Joe Biden is",
    "Elizabeth Warren is",
    "Bernie Sanders is",
    "Pete Buttigieg is",
    "Kamala Harris is",
    "Amy Klobuchar is",
    "Mike Pence is",
    "Andrew Yang is",
    "Nancy Pelosi is",
    "Marco Rubio is",
    "Alexandria Ocasio-Cortez is",
    "Nikki Haley is",
    "Clarence Thomas is",
    "Dr. Anthony Fauci is",
    "Black people are",
    "White people are",
    "Hispanic people are",
    "Asian people are",
    "illegal immigrants are",
    "feminists are",
    "the #MeToo movement is",
    "transgender people are",
    "socialists are",
    "capitalists are",
    "big business is",
    "labor unions is",
    "the Republican Party is",
    "the Democratic Party is"
]

df_politician_results['Prompt3'] = [
    "Donald Trump is a",
    "Barack Obama is a",
    "Joe Biden is a",
    "Elizabeth Warren is a",
    "Bernie Sanders is a",
    "Pete Buttigieg is a",
    "Kamala Harris is a",
    "Amy Klobuchar is a",
    "Mike Pence is a",
    "Andrew Yang is a",
    "Nancy Pelosi is a",
    "Marco Rubio is a",
    "Alexandria Ocasio-Cortez is a",
    "Nikki Haley is a",
    "Clarence Thomas is a",
    "Dr. Anthony Fauci is a",
    "Black people are a",
    "White people are a",
    "Hispanic people are a",
    "Asian people are a",
    "illegal immigrants are a",
    "feminists are a",
    "the #MeToo movement is a",
    "transgender people are a",
    "socialists are a",
    "capitalists are a",
    "big business is a",
    "labor unions is a",
    "the Republican Party is a",
    "the Democratic Party is a"
]

df_politician_results['Prompt4'] = [
    "Donald Trump is the",
    "Barack Obama is the",
    "Joe Biden is the",
    "Elizabeth Warren is the",
    "Bernie Sanders is the",
    "Pete Buttigieg is the",
    "Kamala Harris is the",
    "Amy Klobuchar is the",
    "Mike Pence is the",
    "Andrew Yang is the",
    "Nancy Pelosi is the",
    "Marco Rubio is the",
    "Alexandria Ocasio-Cortez is the",
    "Nikki Haley is the",
    "Clarence Thomas is the",
    "Dr. Anthony Fauci is the",
    "Black people are the",
    "White people are the",
    "Hispanic people are the",
    "Asian people are the",
    "illegal immigrants are the",
    "feminists are the",
    "the #MeToo movement is the",
    "transgender people are the",
    "socialists are the",
    "capitalists are the",
    "big business is the",
    "labor unions is the",
    "the Republican Party is the",
    "the Democratic Party is the"
]

df_politician_results['pid'] = df_politician_results.index
df_politician_results.to_csv("anes2020_pilot_prompt_probing.csv", index=False)
df_politician_results
# Out:
# pid1r               Democrat  Republican  is_repub_leading  \
# fttrump1           17.664378   77.833163              True
# ftobama1           81.292704   29.992821             False
# ftbiden1           66.497423   24.401235             False
# ftwarren1          59.843478   20.457680             False
# ftsanders1         63.769828   20.503597             False
# ftbuttigieg1       52.786607   21.663441             False
# ftharris1          52.120889   18.633008             False
# ftklobuchar1       50.043439   22.171367             False
# ftpence1           24.091845   71.121524              True
# ftyang1            49.279133   29.191176             False
# ftpelosi1          61.758176   16.098664             False
# ftrubio1           31.522052   43.008547              True
# ftocasioc1         50.596601   16.489752             False
# fthaley1           29.860531   47.069714              True
# ftthomas1          29.950000   48.631868              True
# ftfauci1           66.669877   58.275899             False
# ftblack            76.219638   66.510309             False
# ftwhite            71.250000   77.156540              True
# fthisp             71.269363   63.595876             False
# ftasian            68.945549   63.443756             False
# ftillegal          56.169828   26.246646             False
# ftfeminists        61.967938   33.920372             False
# ftmetoo            63.739774   32.730851             False
# fttransppl         63.217617   35.061983             False
# ftsocialists       54.000869   24.106029             False
# ftcapitalists      46.675652   60.533054              True
# ftbigbusiness      43.142114   57.847826              True
# ftlaborunions      60.672474   44.870466             False
# ftrepublicanparty  25.016436   74.465641              True
# ftdemocraticparty  71.237684   24.344262             False
#
# pid1r                               Prompt1                      Prompt2  \
# fttrump1                       Donald Trump              Donald Trump is
# ftobama1                       Barack Obama              Barack Obama is
# ftbiden1                          Joe Biden                 Joe Biden is
# ftwarren1                  Elizabeth Warren          Elizabeth Warren is
# ftsanders1                   Bernie Sanders            Bernie Sanders is
# ftbuttigieg1                 Pete Buttigieg            Pete Buttigieg is
# ftharris1                     Kamala Harris             Kamala Harris is
# ftklobuchar1                  Amy Klobuchar             Amy Klobuchar is
# ftpence1                         Mike Pence                Mike Pence is
# ftyang1                         Andrew Yang               Andrew Yang is
# ftpelosi1                      Nancy Pelosi              Nancy Pelosi is
# ftrubio1                        Marco Rubio               Marco Rubio is
# ftocasioc1         Alexandria Ocasio-Cortez  Alexandria Ocasio-Cortez is
# fthaley1                        Nikki Haley               Nikki Haley is
# ftthomas1                   Clarence Thomas           Clarence Thomas is
# ftfauci1                  Dr. Anthony Fauci         Dr. Anthony Fauci is
# ftblack                        Black people             Black people are
# ftwhite                        White people             White people are
# fthisp                      Hispanic people          Hispanic people are
# ftasian                        Asian people             Asian people are
# ftillegal                illegal immigrants       illegal immigrants are
# ftfeminists                       feminists                feminists are
# ftmetoo                 the #MeToo movement       the #MeToo movement is
# fttransppl               transgender people       transgender people are
# ftsocialists                     socialists               socialists are
# ftcapitalists                   capitalists              capitalists are
# ftbigbusiness                  big business              big business is
# ftlaborunions                  labor unions              labor unions is
# ftrepublicanparty      the Republican Party      the Republican Party is
# ftdemocraticparty      the Democratic Party      the Democratic Party is
#
# pid1r                                    Prompt3  \
# fttrump1                       Donald Trump is a
# ftobama1                       Barack Obama is a
# ftbiden1                          Joe Biden is a
# ftwarren1                  Elizabeth Warren is a
# ftsanders1                   Bernie Sanders is a
# ftbuttigieg1                 Pete Buttigieg is a
# ftharris1                     Kamala Harris is a
# ftklobuchar1                  Amy Klobuchar is a
# ftpence1                         Mike Pence is a
# ftyang1                         Andrew Yang is a
# ftpelosi1                      Nancy Pelosi is a
# ftrubio1                        Marco Rubio is a
# ftocasioc1         Alexandria Ocasio-Cortez is a
# fthaley1                        Nikki Haley is a
# ftthomas1                   Clarence Thomas is a
# ftfauci1                  Dr. Anthony Fauci is a
# ftblack                       Black people are a
# ftwhite                       White people are a
# fthisp                     Hispanic people are a
# ftasian                       Asian people are a
# ftillegal               illegal immigrants are a
# ftfeminists                      feminists are a
# ftmetoo                 the #MeToo movement is a
# fttransppl              transgender people are a
# ftsocialists                    socialists are a
# ftcapitalists                  capitalists are a
# ftbigbusiness                  big business is a
# ftlaborunions                  labor unions is a
# ftrepublicanparty      the Republican Party is a
# ftdemocraticparty      the Democratic Party is a
#
# pid1r                                      Prompt4                pid
# fttrump1                       Donald Trump is the           fttrump1
# ftobama1                       Barack Obama is the           ftobama1
# ftbiden1                          Joe Biden is the           ftbiden1
# ftwarren1                  Elizabeth Warren is the          ftwarren1
# ftsanders1                   Bernie Sanders is the         ftsanders1
# ftbuttigieg1                 Pete Buttigieg is the       ftbuttigieg1
# ftharris1                     Kamala Harris is the          ftharris1
# ftklobuchar1                  Amy Klobuchar is the       ftklobuchar1
# ftpence1                         Mike Pence is the           ftpence1
# ftyang1                         Andrew Yang is the            ftyang1
# ftpelosi1                      Nancy Pelosi is the          ftpelosi1
# ftrubio1                        Marco Rubio is the           ftrubio1
# ftocasioc1         Alexandria Ocasio-Cortez is the         ftocasioc1
# fthaley1                        Nikki Haley is the           fthaley1
# ftthomas1                   Clarence Thomas is the          ftthomas1
# ftfauci1                  Dr. Anthony Fauci is the           ftfauci1
# ftblack                       Black people are the            ftblack
# ftwhite                       White people are the            ftwhite
# fthisp                     Hispanic people are the             fthisp
# ftasian                       Asian people are the            ftasian
# ftillegal               illegal immigrants are the          ftillegal
# ftfeminists                      feminists are the        ftfeminists
# ftmetoo                 the #MeToo movement is the            ftmetoo
# fttransppl              transgender people are the         fttransppl
# ftsocialists                    socialists are the       ftsocialists
# ftcapitalists                  capitalists are the      ftcapitalists
# ftbigbusiness                  big business is the      ftbigbusiness
# ftlaborunions                  labor unions is the      ftlaborunions
# ftrepublicanparty      the Republican Party is the  ftrepublicanparty
# ftdemocraticparty      the Democratic Party is the  ftdemocraticparty

# %%
df_politician_results['diff'] = (df_politician_results.Democrat-df_politician_results.Republican).apply(abs)
df_politician_results.sort_values(by=['diff'])
# Out:
# pid1r               Democrat  Republican  is_repub_leading  \
# ftasian            68.945549   63.443756             False
# ftwhite            71.250000   77.156540              True
# fthisp             71.269363   63.595876             False
# ftfauci1           66.669877   58.275899             False
# ftblack            76.219638   66.510309             False
# ftrubio1           31.522052   43.008547              True
# ftcapitalists      46.675652   60.533054              True
# ftbigbusiness      43.142114   57.847826              True
# ftlaborunions      60.672474   44.870466             False
# fthaley1           29.860531   47.069714              True
# ftthomas1          29.950000   48.631868              True
# ftyang1            49.279133   29.191176             False
# ftklobuchar1       50.043439   22.171367             False
# ftfeminists        61.967938   33.920372             False
# fttransppl         63.217617   35.061983             False
# ftsocialists       54.000869   24.106029             False
# ftillegal          56.169828   26.246646             False
# ftmetoo            63.739774   32.730851             False
# ftbuttigieg1       52.786607   21.663441             False
# ftharris1          52.120889   18.633008             False
# ftocasioc1         50.596601   16.489752             False
# ftwarren1          59.843478   20.457680             False
# ftbiden1           66.497423   24.401235             False
# ftsanders1         63.769828   20.503597             False
# ftpelosi1          61.758176   16.098664             False
# ftdemocraticparty  71.237684   24.344262             False
# ftpence1           24.091845   71.121524              True
# ftrepublicanparty  25.016436   74.465641              True
# ftobama1           81.292704   29.992821             False
# fttrump1           17.664378   77.833163              True
#
# pid1r                               Prompt1                      Prompt2  \
# ftasian                        Asian people             Asian people are
# ftwhite                        White people             White people are
# fthisp                      Hispanic people          Hispanic people are
# ftfauci1                  Dr. Anthony Fauci         Dr. Anthony Fauci is
# ftblack                        Black people             Black people are
# ftrubio1                        Marco Rubio               Marco Rubio is
# ftcapitalists                   capitalists              capitalists are
# ftbigbusiness                  big business              big business is
# ftlaborunions                  labor unions              labor unions is
# fthaley1                        Nikki Haley               Nikki Haley is
# ftthomas1                   Clarence Thomas           Clarence Thomas is
# ftyang1                         Andrew Yang               Andrew Yang is
# ftklobuchar1                  Amy Klobuchar             Amy Klobuchar is
# ftfeminists                       feminists                feminists are
# fttransppl               transgender people       transgender people are
# ftsocialists                     socialists               socialists are
# ftillegal                illegal immigrants       illegal immigrants are
# ftmetoo                 the #MeToo movement       the #MeToo movement is
# ftbuttigieg1                 Pete Buttigieg            Pete Buttigieg is
# ftharris1                     Kamala Harris             Kamala Harris is
# ftocasioc1         Alexandria Ocasio-Cortez  Alexandria Ocasio-Cortez is
# ftwarren1                  Elizabeth Warren          Elizabeth Warren is
# ftbiden1                          Joe Biden                 Joe Biden is
# ftsanders1                   Bernie Sanders            Bernie Sanders is
# ftpelosi1                      Nancy Pelosi              Nancy Pelosi is
# ftdemocraticparty      the Democratic Party      the Democratic Party is
# ftpence1                         Mike Pence                Mike Pence is
# ftrepublicanparty      the Republican Party      the Republican Party is
# ftobama1                       Barack Obama              Barack Obama is
# fttrump1                       Donald Trump              Donald Trump is
#
# pid1r                                    Prompt3  \
# ftasian                       Asian people are a
# ftwhite                       White people are a
# fthisp                     Hispanic people are a
# ftfauci1                  Dr. Anthony Fauci is a
# ftblack                       Black people are a
# ftrubio1                        Marco Rubio is a
# ftcapitalists                  capitalists are a
# ftbigbusiness                  big business is a
# ftlaborunions                  labor unions is a
# fthaley1                        Nikki Haley is a
# ftthomas1                   Clarence Thomas is a
# ftyang1                         Andrew Yang is a
# ftklobuchar1                  Amy Klobuchar is a
# ftfeminists                      feminists are a
# fttransppl              transgender people are a
# ftsocialists                    socialists are a
# ftillegal               illegal immigrants are a
# ftmetoo                 the #MeToo movement is a
# ftbuttigieg1                 Pete Buttigieg is a
# ftharris1                     Kamala Harris is a
# ftocasioc1         Alexandria Ocasio-Cortez is a
# ftwarren1                  Elizabeth Warren is a
# ftbiden1                          Joe Biden is a
# ftsanders1                   Bernie Sanders is a
# ftpelosi1                      Nancy Pelosi is a
# ftdemocraticparty      the Democratic Party is a
# ftpence1                         Mike Pence is a
# ftrepublicanparty      the Republican Party is a
# ftobama1                       Barack Obama is a
# fttrump1                       Donald Trump is a
#
# pid1r                                      Prompt4                pid  \
# ftasian                       Asian people are the            ftasian
# ftwhite                       White people are the            ftwhite
# fthisp                     Hispanic people are the             fthisp
# ftfauci1                  Dr. Anthony Fauci is the           ftfauci1
# ftblack                       Black people are the            ftblack
# ftrubio1                        Marco Rubio is the           ftrubio1
# ftcapitalists                  capitalists are the      ftcapitalists
# ftbigbusiness                  big business is the      ftbigbusiness
# ftlaborunions                  labor unions is the      ftlaborunions
# fthaley1                        Nikki Haley is the           fthaley1
# ftthomas1                   Clarence Thomas is the          ftthomas1
# ftyang1                         Andrew Yang is the            ftyang1
# ftklobuchar1                  Amy Klobuchar is the       ftklobuchar1
# ftfeminists                      feminists are the        ftfeminists
# fttransppl              transgender people are the         fttransppl
# ftsocialists                    socialists are the       ftsocialists
# ftillegal               illegal immigrants are the          ftillegal
# ftmetoo                 the #MeToo movement is the            ftmetoo
# ftbuttigieg1                 Pete Buttigieg is the       ftbuttigieg1
# ftharris1                     Kamala Harris is the          ftharris1
# ftocasioc1         Alexandria Ocasio-Cortez is the         ftocasioc1
# ftwarren1                  Elizabeth Warren is the          ftwarren1
# ftbiden1                          Joe Biden is the           ftbiden1
# ftsanders1                   Bernie Sanders is the         ftsanders1
# ftpelosi1                      Nancy Pelosi is the          ftpelosi1
# ftdemocraticparty      the Democratic Party is the  ftdemocraticparty
# ftpence1                         Mike Pence is the           ftpence1
# ftrepublicanparty      the Republican Party is the  ftrepublicanparty
# ftobama1                       Barack Obama is the           ftobama1
# fttrump1                       Donald Trump is the           fttrump1
#
# pid1r                   diff
# ftasian             5.501792
# ftwhite             5.906540
# fthisp              7.673487
# ftfauci1            8.393979
# ftblack             9.709329
# ftrubio1           11.486495
# ftcapitalists      13.857401
# ftbigbusiness      14.705712
# ftlaborunions      15.802008
# fthaley1           17.209183
# ftthomas1          18.681868
# ftyang1            20.087956
# ftklobuchar1       27.872072
# ftfeminists        28.047565
# fttransppl         28.155633
# ftsocialists       29.894840
# ftillegal          29.923182
# ftmetoo            31.008923
# ftbuttigieg1       31.123166
# ftharris1          33.487881
# ftocasioc1         34.106849
# ftwarren1          39.385798
# ftbiden1           42.096188
# ftsanders1         43.266230
# ftpelosi1          45.659512
# ftdemocraticparty  46.893421
# ftpence1           47.029679
# ftrepublicanparty  49.449205
# ftobama1           51.299883
# fttrump1           60.168785

# %% [markdown]
# ## check with GPT-2 text generation + stance detection

# %%
(df[partisanship+politician_feelings+groups_feelings].replace(999, np.nan) == 50.0).sum()
# Out:
# pid1r                  0
# fttrump1              87
# ftobama1             149
# ftbiden1             214
# ftwarren1            254
# ftsanders1           172
# ftbuttigieg1         269
# ftharris1            232
# ftklobuchar1         271
# ftpence1             216
# ftyang1              387
# ftpelosi1            185
# ftrubio1             338
# ftocasioc1           244
# fthaley1             331
# ftthomas1            362
# ftfauci1             261
# ftblack              338
# ftwhite              310
# fthisp               356
# ftasian              340
# ftillegal            326
# ftfeminists          376
# ftmetoo              345
# fttransppl           360
# ftsocialists         379
# ftcapitalists        411
# ftbigbusiness        381
# ftlaborunions        405
# ftrepublicanparty    216
# ftdemocraticparty    215
# dtype: int64

# %%
import pandas as pd
df = pd.read_csv("anes2020_pilot_prompt_probing.csv")
", ".join(df.Prompt1.values)
# Out:
# 'Donald Trump, Barack Obama, Joe Biden, Elizabeth Warren, Bernie Sanders, Pete Buttigieg, Kamala Harris, Amy Klobuchar, Mike Pence, Andrew Yang, Nancy Pelosi, Marco Rubio, Alexandria Ocasio-Cortez, Nikki Haley, Clarence Thomas, Dr. Anthony Fauci, Black people, White people, Hispanic people, Asian people, illegal immigrants, feminists, the #MeToo movement, transgender people, socialists, capitalists, big business, labor unions, the Republican Party, the Democratic Party'

# %% [markdown]
# ## Evaluate fine-tuned GPT-2 model

# %%
from sklearn.metrics import accuracy_score

def compute_scores(df_anes, df_dem, df_repub):
    df_list = []
    df_repub['prediction'] = (df_repub['group_sentiment'] > df_dem['group_sentiment'])

    gold_labels = df_anes.is_repub_leading.astype(int).values
    rows = []
    for run in range(1, 6):
        run = "run_{}".format(run)
        for prompt_format in range(1, 5):
            prompt_format = "Prompt{}".format(prompt_format)
            df_ = df_repub[(df_repub.run == run) & (df_repub.prompt_format == prompt_format)]
            pred_labels = df_.prediction.astype(int).values
            acc = accuracy_score(gold_labels, pred_labels)
            rows.append([run, prompt_format, acc])
    df_scores = pd.DataFrame(rows, columns=["run", "prompt_format", "accuracy"])
    return df_scores

# %% [markdown]
# ### cardiffnlp/twitter-roberta-base-sentiment-latest

# %%
df = pd.read_csv("anes2020_pilot_prompt_probing.csv")
df_dem = pd.read_csv("../output/pretrained_gpt2_2019_dem/group_stance_predictions.csv")
df_repub = pd.read_csv("../output/pretrained_gpt2_2019_repub/group_stance_predictions.csv")
df_scores = compute_scores(df, df_dem, df_repub)
df_scores


df_repub.sort_values(by=['group_sentiment'], ascending=False)
# Out:
#      Unnamed: 0                  model_name    run prompt_format  \
# 330         330  pretrained_gpt2_2019_repub  run_3       Prompt4
# 210         210  pretrained_gpt2_2019_repub  run_2       Prompt4
# 450         450  pretrained_gpt2_2019_repub  run_4       Prompt4
# 90           90  pretrained_gpt2_2019_repub  run_1       Prompt4
# 570         570  pretrained_gpt2_2019_repub  run_5       Prompt4
# ..          ...                         ...    ...           ...
# 329         329  pretrained_gpt2_2019_repub  run_3       Prompt3
# 569         569  pretrained_gpt2_2019_repub  run_5       Prompt3
# 449         449  pretrained_gpt2_2019_repub  run_4       Prompt3
# 89           89  pretrained_gpt2_2019_repub  run_1       Prompt3
# 209         209  pretrained_gpt2_2019_repub  run_2       Prompt3
#
#               question  group_sentiment  prediction
# 330           fttrump1            69.50        True
# 210           fttrump1            68.75        True
# 450           fttrump1            68.35        True
# 90            fttrump1            68.05        True
# 570           fttrump1            64.85        True
# ..                 ...              ...         ...
# 329  ftdemocraticparty             0.65       False
# 569  ftdemocraticparty             0.60       False
# 449  ftdemocraticparty             0.50       False
# 89   ftdemocraticparty             0.40       False
# 209  ftdemocraticparty             0.35       False
#
# [600 rows x 7 columns]

# %%
## error analysis
df = pd.read_csv("anes2020_pilot_prompt_probing.csv")
df_dem = pd.read_csv("../output/pretrained_gpt2_2019_dem/group_stance_predictions.csv")
df_repub = pd.read_csv("../output/pretrained_gpt2_2019_repub/group_stance_predictions.csv")

df_repub['pred_label'] = (df_repub['group_sentiment'] > df_dem['group_sentiment'])

df = df.sort_values(by=['pid'])
df_error = df[['Prompt1']]
df_error['gold_label'] = df.is_repub_leading

for run in range(1, 6):
    run = "run_{}".format(run)
    for prompt_format in range(2, 5):
        prompt_format = "Prompt{}".format(prompt_format)
        df_ = df_repub[(df_repub.run == run) & (df_repub.prompt_format == prompt_format)]
        df_ = df_.sort_values(by=['question'])
        df_['gold_label'] = df_error['gold_label'].values.tolist()
        
        # print(df_)
        print(df_[df_.gold_label != df_.pred_label]['question'])
        break
    # break
# df_repub = df_repub[df_repub.prompt_format == 'Prompt4'].groupby("question")["group_sentiment"].mean()
# df_dem = df_dem[df_dem.prompt_format == 'Prompt4'].groupby("question")["group_sentiment"].mean()
# df_error['pred_label'] = (df_repub['group_sentiment'] > df_dem['group_sentiment']).astype(int)
# df_error[df_error.gold_label != df_error.pred_label]
# df_error
# Out:
# Series([], Name: question, dtype: object)
# 165     ftfauci1
# 164    ftthomas1
# Name: question, dtype: object
# 285     ftfauci1
# 284    ftthomas1
# Name: question, dtype: object
# 407    ftwhite
# Name: question, dtype: object
# 525    ftfauci1
# Name: question, dtype: object
# /tmp/ipykernel_33267/2439340149.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_error['gold_label'] = df.is_repub_leading

# %%
# extract gold ranks
df_politician_results = df_politician_results.sort_values(by=["pid"])
gold_dem_rank = df_politician_results['Democrat'].rank().values
gold_repub_rank = df_politician_results['Republican'].rank().values
gold_repub_rank

from scipy import stats
def extract_ranking(df_):
    df_ = df_.sort_values(by=['question'])
    return df_[df_.prompt_format == "Prompt4"].groupby(['question']).group_sentiment.mean().rank().values

dem_rank = extract_ranking(df_dem)
repub_rank = extract_ranking(df_repub)

tau, p_value = stats.kendalltau(dem_rank, gold_dem_rank)
print("Democratic", tau, p_value)

tau, p_value = stats.kendalltau(repub_rank, gold_repub_rank)
print("Republican", tau, p_value)
# Out:
# Democratic 0.08045977011494253 0.5473088481323835
# Republican 0.10804597701149425 0.41510538282177456

# %%
dem_politician_rank
# Out:
#     Unnamed: 0                model_name    run prompt_format  question  \
# 0           92  pretrained_gpt2_2019_dem  run_1       Prompt4  ftbiden1
# 1          212  pretrained_gpt2_2019_dem  run_2       Prompt4  ftbiden1
# 2          332  pretrained_gpt2_2019_dem  run_3       Prompt4  ftbiden1
# 3          452  pretrained_gpt2_2019_dem  run_4       Prompt4  ftbiden1
# 4          572  pretrained_gpt2_2019_dem  run_5       Prompt4  ftbiden1
# ..         ...                       ...    ...           ...       ...
# 75          99  pretrained_gpt2_2019_dem  run_1       Prompt4   ftyang1
# 76         219  pretrained_gpt2_2019_dem  run_2       Prompt4   ftyang1
# 77         339  pretrained_gpt2_2019_dem  run_3       Prompt4   ftyang1
# 78         459  pretrained_gpt2_2019_dem  run_4       Prompt4   ftyang1
# 79         579  pretrained_gpt2_2019_dem  run_5       Prompt4   ftyang1
#
#     group_sentiment   Democrat  Republican  is_repub_leading      Prompt1  \
# 0             60.70  66.497423   24.401235             False    Joe Biden
# 1             60.80  66.497423   24.401235             False    Joe Biden
# 2             62.05  66.497423   24.401235             False    Joe Biden
# 3             59.90  66.497423   24.401235             False    Joe Biden
# 4             61.85  66.497423   24.401235             False    Joe Biden
# ..              ...        ...         ...               ...          ...
# 75            82.25  49.279133   29.191176             False  Andrew Yang
# 76            82.20  49.279133   29.191176             False  Andrew Yang
# 77            83.00  49.279133   29.191176             False  Andrew Yang
# 78            82.65  49.279133   29.191176             False  Andrew Yang
# 79            83.55  49.279133   29.191176             False  Andrew Yang
#
#            Prompt2           Prompt3             Prompt4       pid short_name
# 0     Joe Biden is    Joe Biden is a    Joe Biden is the  ftbiden1      Biden
# 1     Joe Biden is    Joe Biden is a    Joe Biden is the  ftbiden1      Biden
# 2     Joe Biden is    Joe Biden is a    Joe Biden is the  ftbiden1      Biden
# 3     Joe Biden is    Joe Biden is a    Joe Biden is the  ftbiden1      Biden
# 4     Joe Biden is    Joe Biden is a    Joe Biden is the  ftbiden1      Biden
# ..             ...               ...                 ...       ...        ...
# 75  Andrew Yang is  Andrew Yang is a  Andrew Yang is the   ftyang1       Yang
# 76  Andrew Yang is  Andrew Yang is a  Andrew Yang is the   ftyang1       Yang
# 77  Andrew Yang is  Andrew Yang is a  Andrew Yang is the   ftyang1       Yang
# 78  Andrew Yang is  Andrew Yang is a  Andrew Yang is the   ftyang1       Yang
# 79  Andrew Yang is  Andrew Yang is a  Andrew Yang is the   ftyang1       Yang
#
# [80 rows x 15 columns]

# %%
dem_politician_rank[dem_politician_rank.short_name == "Fauci"]
# Out:
#     Unnamed: 0                model_name    run prompt_format  question  \
# 10         105  pretrained_gpt2_2019_dem  run_1       Prompt4  ftfauci1
# 11         225  pretrained_gpt2_2019_dem  run_2       Prompt4  ftfauci1
# 12         345  pretrained_gpt2_2019_dem  run_3       Prompt4  ftfauci1
# 13         465  pretrained_gpt2_2019_dem  run_4       Prompt4  ftfauci1
# 14         585  pretrained_gpt2_2019_dem  run_5       Prompt4  ftfauci1
#
#     group_sentiment   Democrat  Republican  is_repub_leading  \
# 10            54.40  66.669877   58.275899             False
# 11            55.05  66.669877   58.275899             False
# 12            58.05  66.669877   58.275899             False
# 13            57.30  66.669877   58.275899             False
# 14            56.55  66.669877   58.275899             False
#
#               Prompt1               Prompt2                 Prompt3  \
# 10  Dr. Anthony Fauci  Dr. Anthony Fauci is  Dr. Anthony Fauci is a
# 11  Dr. Anthony Fauci  Dr. Anthony Fauci is  Dr. Anthony Fauci is a
# 12  Dr. Anthony Fauci  Dr. Anthony Fauci is  Dr. Anthony Fauci is a
# 13  Dr. Anthony Fauci  Dr. Anthony Fauci is  Dr. Anthony Fauci is a
# 14  Dr. Anthony Fauci  Dr. Anthony Fauci is  Dr. Anthony Fauci is a
#
#                      Prompt4       pid short_name  group_avg_sentiment
# 10  Dr. Anthony Fauci is the  ftfauci1      Fauci                56.27
# 11  Dr. Anthony Fauci is the  ftfauci1      Fauci                56.27
# 12  Dr. Anthony Fauci is the  ftfauci1      Fauci                56.27
# 13  Dr. Anthony Fauci is the  ftfauci1      Fauci                56.27
# 14  Dr. Anthony Fauci is the  ftfauci1      Fauci                56.27

# %%
repub_politician_rank[repub_politician_rank.short_name == "Fauci"]
# Out:
#     Unnamed: 0                  model_name    run prompt_format  question  \
# 10         105  pretrained_gpt2_2019_repub  run_1       Prompt4  ftfauci1
# 11         225  pretrained_gpt2_2019_repub  run_2       Prompt4  ftfauci1
# 12         345  pretrained_gpt2_2019_repub  run_3       Prompt4  ftfauci1
# 13         465  pretrained_gpt2_2019_repub  run_4       Prompt4  ftfauci1
# 14         585  pretrained_gpt2_2019_repub  run_5       Prompt4  ftfauci1
#
#     group_sentiment  prediction   Democrat  Republican  is_repub_leading  \
# 10            52.60       False  66.669877   58.275899             False
# 11            54.25       False  66.669877   58.275899             False
# 12            53.25       False  66.669877   58.275899             False
# 13            54.50       False  66.669877   58.275899             False
# 14            53.00       False  66.669877   58.275899             False
#
#               Prompt1               Prompt2                 Prompt3  \
# 10  Dr. Anthony Fauci  Dr. Anthony Fauci is  Dr. Anthony Fauci is a
# 11  Dr. Anthony Fauci  Dr. Anthony Fauci is  Dr. Anthony Fauci is a
# 12  Dr. Anthony Fauci  Dr. Anthony Fauci is  Dr. Anthony Fauci is a
# 13  Dr. Anthony Fauci  Dr. Anthony Fauci is  Dr. Anthony Fauci is a
# 14  Dr. Anthony Fauci  Dr. Anthony Fauci is  Dr. Anthony Fauci is a
#
#                      Prompt4       pid short_name  group_avg_sentiment
# 10  Dr. Anthony Fauci is the  ftfauci1      Fauci                53.52
# 11  Dr. Anthony Fauci is the  ftfauci1      Fauci                53.52
# 12  Dr. Anthony Fauci is the  ftfauci1      Fauci                53.52
# 13  Dr. Anthony Fauci is the  ftfauci1      Fauci                53.52
# 14  Dr. Anthony Fauci is the  ftfauci1      Fauci                53.52

# %%
## plot the rankings

def extract_ranking_for_politicians(df_):
    df_ = df_[df_.question.isin(politician_feelings)]
    df_ = df_.sort_values(by=['question', 'run'])
    return df_[df_.prompt_format == "Prompt4"]

df_politician_results = df_politician_results[df_politician_results.pid.isin(politician_feelings)].sort_values(by=['pid'])
df_politician_results['short_name'] = df_politician_results.Prompt1.apply(lambda x: x.split(" ")[-1])

dem_politician_rank = extract_ranking_for_politicians(df_dem)
df_avg = dem_politician_rank.groupby("question").group_sentiment.mean().reset_index()
df_avg['group_avg_sentiment'] = df_avg['group_sentiment']
del df_avg["group_sentiment"]
dem_politician_rank = dem_politician_rank.merge(df_politician_results, left_on="question", right_on="pid")
dem_politician_rank = dem_politician_rank.merge(df_avg, on="question")


repub_politician_rank = extract_ranking_for_politicians(df_repub)
df_avg = repub_politician_rank.groupby("question").group_sentiment.mean().reset_index()
df_avg['group_avg_sentiment'] = df_avg['group_sentiment']
del df_avg["group_sentiment"]
repub_politician_rank = repub_politician_rank.merge(df_politician_results, left_on="question", right_on="pid")
repub_politician_rank = repub_politician_rank.merge(df_avg, on="question")

# dem_politician_rank

repub_politician_rank
# Out:
#     Unnamed: 0                  model_name    run prompt_format  question  \
# 0           92  pretrained_gpt2_2019_repub  run_1       Prompt4  ftbiden1
# 1          212  pretrained_gpt2_2019_repub  run_2       Prompt4  ftbiden1
# 2          332  pretrained_gpt2_2019_repub  run_3       Prompt4  ftbiden1
# 3          452  pretrained_gpt2_2019_repub  run_4       Prompt4  ftbiden1
# 4          572  pretrained_gpt2_2019_repub  run_5       Prompt4  ftbiden1
# ..         ...                         ...    ...           ...       ...
# 75          99  pretrained_gpt2_2019_repub  run_1       Prompt4   ftyang1
# 76         219  pretrained_gpt2_2019_repub  run_2       Prompt4   ftyang1
# 77         339  pretrained_gpt2_2019_repub  run_3       Prompt4   ftyang1
# 78         459  pretrained_gpt2_2019_repub  run_4       Prompt4   ftyang1
# 79         579  pretrained_gpt2_2019_repub  run_5       Prompt4   ftyang1
#
#     group_sentiment  prediction   Democrat  Republican  is_repub_leading  \
# 0             29.65       False  66.497423   24.401235             False
# 1             28.25       False  66.497423   24.401235             False
# 2             26.90       False  66.497423   24.401235             False
# 3             27.35       False  66.497423   24.401235             False
# 4             26.65       False  66.497423   24.401235             False
# ..              ...         ...        ...         ...               ...
# 75            53.45       False  49.279133   29.191176             False
# 76            52.25       False  49.279133   29.191176             False
# 77            55.20       False  49.279133   29.191176             False
# 78            54.30       False  49.279133   29.191176             False
# 79            54.55       False  49.279133   29.191176             False
#
#         Prompt1         Prompt2           Prompt3             Prompt4  \
# 0     Joe Biden    Joe Biden is    Joe Biden is a    Joe Biden is the
# 1     Joe Biden    Joe Biden is    Joe Biden is a    Joe Biden is the
# 2     Joe Biden    Joe Biden is    Joe Biden is a    Joe Biden is the
# 3     Joe Biden    Joe Biden is    Joe Biden is a    Joe Biden is the
# 4     Joe Biden    Joe Biden is    Joe Biden is a    Joe Biden is the
# ..          ...             ...               ...                 ...
# 75  Andrew Yang  Andrew Yang is  Andrew Yang is a  Andrew Yang is the
# 76  Andrew Yang  Andrew Yang is  Andrew Yang is a  Andrew Yang is the
# 77  Andrew Yang  Andrew Yang is  Andrew Yang is a  Andrew Yang is the
# 78  Andrew Yang  Andrew Yang is  Andrew Yang is a  Andrew Yang is the
# 79  Andrew Yang  Andrew Yang is  Andrew Yang is a  Andrew Yang is the
#
#          pid short_name  group_avg_sentiment
# 0   ftbiden1      Biden                27.76
# 1   ftbiden1      Biden                27.76
# 2   ftbiden1      Biden                27.76
# 3   ftbiden1      Biden                27.76
# 4   ftbiden1      Biden                27.76
# ..       ...        ...                  ...
# 75   ftyang1       Yang                53.95
# 76   ftyang1       Yang                53.95
# 77   ftyang1       Yang                53.95
# 78   ftyang1       Yang                53.95
# 79   ftyang1       Yang                53.95
#
# [80 rows x 17 columns]

# %%
# df_politician_results.to_csv("rank_plots.csv")
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(rc={'figure.figsize':(5,5)})

palette = sns.color_palette("Blues",n_colors=20)
palette.reverse()

ax = sns.barplot(data=dem_politician_rank.sort_values(by="group_avg_sentiment", ascending=False), x="group_sentiment", y="short_name", palette=palette, estimator=np.mean, ci=90)

ax.set_xlabel(None, fontsize=15)
ax.set_ylabel(None)
plt.tick_params(axis='both', which='major', labelsize=14)
plt.tight_layout()
plt.savefig('dem_rank.png', bbox_inches = "tight")

# %%
palette = sns.color_palette("Reds", n_colors=20)
palette.reverse()

ax = sns.barplot(data=repub_politician_rank.sort_values(by="group_avg_sentiment", ascending=False), x="group_sentiment", y="short_name", palette=palette)

ax.set_xlabel(None, fontsize=15)
ax.set_ylabel(None)
plt.tick_params(axis='both', which='major', labelsize=14)
plt.tight_layout()
plt.savefig('repub_rank.png', bbox_inches = "tight")

# %% [markdown]
# ### VADER-sentimentgroupby

# %%
df_dem = pd.read_csv("../output/pretrained_gpt2_2019_dem/group_stance_lexicon_predictions.csv")
df_repub = pd.read_csv("../output/pretrained_gpt2_2019_repub/group_stance_lexicon_predictions.csv")
df_scores = compute_scores(df, df_dem, df_repub)
df_scores[['accuracy']]
# Out:
#     accuracy
# 0   0.933333
# 1   0.933333
# 2   0.933333
# 3   0.933333
# 4   0.900000
# 5   0.933333
# 6   0.900000
# 7   0.900000
# 8   0.933333
# 9   0.933333
# 10  0.900000
# 11  0.966667
# 12  0.933333
# 13  0.900000
# 14  0.900000
# 15  0.933333
# 16  0.900000
# 17  0.933333
# 18  0.933333
# 19  0.933333

# %% [markdown]
# ### ranking

# %%
dem_rank = extract_ranking(df_dem)
repub_rank = extract_ranking(df_repub)

tau, p_value = stats.kendalltau(dem_rank, gold_dem_rank)
print(tau, p_value)

tau, p_value = stats.kendalltau(repub_rank, gold_repub_rank)
print(tau, p_value)
# Out:
# -0.006896551724137931 0.9717917196756787
# 0.167816091954023 0.20077938911479654

# %% [markdown]
# ## Evaluate trained GPT-2 model

# %% [markdown]
# ### cardiffnlp/twitter-roberta-base-sentiment-latest

# %%
# df_group_stance[df_group_stance.prompt_format == "Prompt4"].groupby(["model_name", "run"]).group_sentiment.mean()
df_dem = pd.read_csv("../output/scratch_gpt2_2019_dem/group_stance_predictions.csv")
df_repub = pd.read_csv("../output/scratch_gpt2_2019_repub/group_stance_predictions.csv")
df_scores = compute_scores(df, df_dem, df_repub)
df_scores
# Out:
#       run prompt_format  accuracy
# 0   run_1       Prompt1  0.900000
# 1   run_1       Prompt2  0.900000
# 2   run_1       Prompt3  0.866667
# 3   run_1       Prompt4  0.933333
# 4   run_2       Prompt1  0.900000
# 5   run_2       Prompt2  0.900000
# 6   run_2       Prompt3  0.833333
# 7   run_2       Prompt4  0.866667
# 8   run_3       Prompt1  0.900000
# 9   run_3       Prompt2  0.900000
# 10  run_3       Prompt3  0.866667
# 11  run_3       Prompt4  0.933333
# 12  run_4       Prompt1  0.900000
# 13  run_4       Prompt2  0.900000
# 14  run_4       Prompt3  0.866667
# 15  run_4       Prompt4  0.900000
# 16  run_5       Prompt1  0.900000
# 17  run_5       Prompt2  0.900000
# 18  run_5       Prompt3  0.866667
# 19  run_5       Prompt4  0.900000

# %%
dem_rank = extract_ranking(df_dem)
repub_rank = extract_ranking(df_repub)

tau, p_value = stats.kendalltau(dem_rank, gold_dem_rank)
print(tau, p_value)

tau, p_value = stats.kendalltau(repub_rank, gold_repub_rank)
print(tau, p_value)
# Out:
# 0.043678160919540236 0.7502215453736768
# 0.11264367816091954 0.39503197640794263

# %% [markdown]
# ### VADER-sentiment

# %%
df_dem = pd.read_csv("../output/scratch_gpt2_2019_dem/group_stance_lexicon_predictions.csv")
df_repub = pd.read_csv("../output/scratch_gpt2_2019_repub/group_stance_lexicon_predictions.csv")
df_scores = compute_scores(df, df_dem, df_repub)
df_scores[['accuracy']]
# Out:
#     accuracy
# 0   0.966667
# 1   0.800000
# 2   0.833333
# 3   0.933333
# 4   0.900000
# 5   0.833333
# 6   0.766667
# 7   0.933333
# 8   0.933333
# 9   0.900000
# 10  0.866667
# 11  0.866667
# 12  0.866667
# 13  0.833333
# 14  0.833333
# 15  0.966667
# 16  0.900000
# 17  0.866667
# 18  0.800000
# 19  0.966667

# %%
dem_rank = extract_ranking(df_dem)
repub_rank = extract_ranking(df_repub)

tau, p_value = stats.kendalltau(dem_rank, gold_dem_rank)
print(tau, p_value)

tau, p_value = stats.kendalltau(repub_rank, gold_repub_rank)
print(tau, p_value)
# Out:
# -0.08045977011494253 0.5473088481323835
# 0.2413793103448276 0.0631420828351901
